# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !gdown --id "1-D_uHkn37M5ptWVQl8a5-q8NBv9jaLWr"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-D_uHkn37M5ptWVQl8a5-q8NBv9jaLWr
# To: /content/RC_2015-01.bz2
# 100% 5.45G/5.45G [01:41<00:00, 53.9MB/s]

# %%
import bz2
import json
n = 2000000
with open("2_milion_sample.txt", "w") as file_out:
    with bz2.BZ2File("RC_2015-01.bz2","rb") as f:
        file_out.write("\n".join([f.readline().decode().strip() for _ in range(n)]))

# %%
# !wget https://downloads.apache.org/hadoop/common/hadoop-3.3.0/hadoop-3.3.0.tar.gz
# Out:
# --2021-11-11 04:42:29--  https://downloads.apache.org/hadoop/common/hadoop-3.3.0/hadoop-3.3.0.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 135.181.214.104, 88.99.95.219, 2a01:4f9:3a:2c57::2, ...
# Connecting to downloads.apache.org (downloads.apache.org)|135.181.214.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 500749234 (478M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.0.tar.gz’
#
# hadoop-3.3.0.tar.gz 100%[===================>] 477.55M  28.6MB/s    in 17s
#
# 2021-11-11 04:42:47 (27.5 MB/s) - ‘hadoop-3.3.0.tar.gz’ saved [500749234/500749234]

# %%
# !tar -xzvf hadoop-3.3.0.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/FSDataOutputStream.html
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/TrashPolicyDefault.Emptier.html
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/HarFileSystem.html
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/PathExistsException.html
# hadoop-3.3.0/share/doc/hadoop/hadoop-project-dist/hadoop-common/build/source/hadoop-common-project/hadoop-common/target/api/org/apache/hadoop/fs/XAttrSetFlag.html
# ...

# %%
# !cp -r hadoop-3.3.0/ /usr/local/

# %%
#To find the default Java path
# !readlink -f /usr/bin/java | sed "s:bin/java::"
# Out:
# /usr/lib/jvm/java-11-openjdk-amd64/

# %%
#Running Hadoop
# !/content/hadoop-3.3.0/bin/hadoop
# Out:
# Usage: hadoop [OPTIONS] SUBCOMMAND [SUBCOMMAND OPTIONS]
#  or    hadoop [OPTIONS] CLASSNAME [CLASSNAME OPTIONS]
#   where CLASSNAME is a user-provided Java class
#
#   OPTIONS is none or any of:
#
# buildpaths                       attempt to add class files from build tree
# --config dir                     Hadoop config directory
# --debug                          turn on shell script debug mode
# --help                           usage information
# hostnames list[,of,host,names]   hosts to use in slave mode
# hosts filename                   list of hosts to use in slave mode
# loglevel level                   set the log4j level for this command
# workers                          turn on worker mode
#
#   SUBCOMMAND is one of:
#
#
#     Admin Commands:
#
# daemonlog     get/set the log level for each daemon
#
#     Client Commands:
#
# archive       create a Hadoop archive
# checknative   check native Hadoop and compression libraries availability
# ...

# %%
# !mkdir ~/input
# !cp /content/hadoop-3.3.0/etc/hadoop/*.xml ~/input

# %%
# !ls ~/input
# Out:
# capacity-scheduler.xml	hdfs-rbf-site.xml  kms-acls.xml     yarn-site.xml
# core-site.xml		hdfs-site.xml	   kms-site.xml
# hadoop-policy.xml	httpfs-site.xml    mapred-site.xml

# %%
# !find / -name 'hadoop-streaming*.jar'
# Out:
# /usr/local/hadoop-3.3.0/share/hadoop/tools/sources/hadoop-streaming-3.3.0-test-sources.jar
# /usr/local/hadoop-3.3.0/share/hadoop/tools/sources/hadoop-streaming-3.3.0-sources.jar
# /usr/local/hadoop-3.3.0/share/hadoop/tools/lib/hadoop-streaming-3.3.0.jar
# /content/hadoop-3.3.0/share/hadoop/tools/sources/hadoop-streaming-3.3.0-test-sources.jar
# /content/hadoop-3.3.0/share/hadoop/tools/sources/hadoop-streaming-3.3.0-sources.jar
# /content/hadoop-3.3.0/share/hadoop/tools/lib/hadoop-streaming-3.3.0.jar

# %%
# !chmod u+rwx /content/mapper.py
# !chmod u+rwx /content/reducer.py

# %%
# !/content/hadoop-3.3.0/bin/hadoop jar /usr/local/hadoop-3.3.0/share/hadoop/tools/lib/hadoop-streaming-3.3.0.jar -input /content/2_milion_sample.txt -output /content/output -file /content/mapper.py  -file /content/reducer.py  -mapper 'python mapper.py'  -reducer 'python reducer.py'
# Out:
# 2021-11-11 06:39:43,814 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/content/mapper.py, /content/reducer.py] [] /tmp/streamjob3226968061959846739.jar tmpDir=null
# 2021-11-11 06:39:44,554 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2021-11-11 06:39:44,720 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2021-11-11 06:39:44,720 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2021-11-11 06:39:44,752 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2021-11-11 06:39:44,926 INFO mapred.FileInputFormat: Total input files to process : 1
# 2021-11-11 06:39:44,956 INFO mapreduce.JobSubmitter: number of splits:35
# 2021-11-11 06:39:45,267 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1278877387_0001
# 2021-11-11 06:39:45,267 INFO mapreduce.JobSubmitter: Executing with tokens: []
# ...

# %%
import shutil

shutil.rmtree('/content/output')

# %%
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# !cat /content/sample_input_1th.txt | python mapper.py | sort | python reducer.py
# Out:
# ['3Dprinting']:topics	[('printer', 6), ('print', 3), ('choic', 2), ('hand', 2), ('part', 2), ('solid', 2), ('time', 2), ('volum', 2), ('well', 2), ('work', 2)]
# ['49ers']:topics	[('one', 1)]
# ['ADHD']:topics	[('descript', 1), ('like', 1), ('think', 1)]
# ['AdviceAnimals']:topics	[('receipt', 6), ('get', 3), ('gift', 3), ('like', 3), ('good', 2), ('know', 2), ('love', 2), ('meme', 2), ('much', 2), ('razor', 2)]
# ['AgainstGamerGate']:topics	[('boy', 1)]
# ['amiibo']:topics	[('box', 1), ('mine', 1), ('open', 1)]
# ['amiugly']:topics	[('like', 2), ('look', 2), ('date', 1), ('face', 1), ('feel', 1), ('fuck', 1), ('good', 1), ('great', 1), ('guy', 1), ('loss', 1)]
# ['Anarcho_Capitalism']:topics	[('entrepreneur', 3), ('monopoli', 3), ('x', 3), ('good', 2), ('price', 2), ('qualiti', 2), ('sell', 2), ('bad', 1), ('better', 1), ('competit', 1)]
# ['androidcirclejerk']:topics	[('worst', 1)]
# ['AndroidQuestions']:topics	[('much', 1), ('one', 1), ('shot', 1), ('troubl', 1)]
# ...
